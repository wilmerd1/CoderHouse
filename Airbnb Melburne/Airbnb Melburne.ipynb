# %% [markdown]
# https://www.kaggle.com/datasets/yuhanhu831/melbourne

# %%
import pandas as pd

# %%
df = pd.read_csv ("D:/Python/DataSet/Airbnb Melburne/listings.csv", sep=',')

# %%
df.shape
# Out:
# (17409, 18)

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17409 entries, 0 to 17408
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              17409 non-null  int64
#  1   name                            17407 non-null  object
#  2   host_id                         17409 non-null  int64
#  3   host_name                       17405 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   17409 non-null  object
#  6   latitude                        17409 non-null  float64
#  7   longitude                       17409 non-null  float64
#  8   room_type                       17409 non-null  object
#  9   price                           17409 non-null  int64
#  10  minimum_nights                  17409 non-null  int64
#  11  number_of_reviews               17409 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df.head(10)
# Out:
#       id                                               name  host_id  \
# 0   9835                             Beautiful Room & House    33057
# 1  12936             St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC    50121
# 2  33111                Million Dollar Views Over Melbourne   143550
# 3  38271                 Melbourne - Old Trafford Apartment   164193
# 4  41836                  CLOSE TO CITY & MELBOURNE AIRPORT   182833
# 5  43429  Tranquil Javanese-Style Apartment in Oakleigh ...   189684
# 6  44082                      Queen Room in Beautiful House   193031
# 7  51592                   Central City Warehouse Apartment   190879
# 8  66754            Richmond CITY EDGE 60s COOL 1BR+WIFI+AC    50121
# 9  67211                         Kew Tranquility, Melbourne   326880
#
#       host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0         Manju                  NaN    Manningham -37.77268  145.09213
# ...

# %%
df.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  1.740900e+04  1.740900e+04                  0.0  17409.000000
# mean   2.941236e+07  1.141079e+08                  NaN    -37.827128
# std    1.504325e+07  1.113817e+08                  NaN      0.072614
# min    9.835000e+03  9.082000e+03                  NaN    -38.224110
# 25%    1.759309e+07  2.350156e+07                  NaN    -37.855460
# 50%    2.978818e+07  7.072784e+07                  NaN    -37.819230
# 75%    4.178045e+07  1.770456e+08                  NaN    -37.800900
# max    5.418953e+07  4.381185e+08                  NaN    -37.482300
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  17409.000000  17409.000000    17409.000000       17409.000000
# mean     145.017436    190.626458        7.054110          26.948590
# std        0.147454    411.494624       35.167185          53.402014
# ...

# %%
pd.unique(df['neighbourhood'])
# Out:
# array(['Manningham', 'Port Phillip', 'Melbourne', 'Casey', 'Darebin',
#        'Monash', 'Frankston', 'Yarra', 'Boroondara', 'Bayside',
#        'Stonnington', 'Glen Eira', 'Kingston', 'Yarra Ranges', 'Banyule',
#        'Moreland', 'Whitehorse', 'Melton', 'Brimbank', 'Hobsons Bay',
#        'Wyndham', 'Moonee Valley', 'Whittlesea', 'Maribyrnong',
#        'Greater Dandenong', 'Knox', 'Maroondah', 'Nillumbik', 'Cardinia',
#        'Hume'], dtype=object)

# %%
pd.unique(df['room_type'])
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
pd.unique(df['minimum_nights'])
# Out:
# array([   1,    3,    7,    2,   14,   21,    4,    5,    6,   30,   10,
#          20,   28,  803,   13,   19,   60,  333,   11,   25,  300,    8,
#         180,  183,    9,   12,   90,   36,   45,  365,  700,  500,  100,
#         185,  182,   40,   31,  400,   15,   50,  900,  360,   99,   18,
#        1124,  600,   16,  200,   91,   80,  120, 1000,  160,   55,   24,
#          22,   33,   17,   92,   29, 1125,  330,   43,   56,  119,   93,
#          70,  356,  150,   23,   63,   83,  130,  128,  175,   35,   95,
#          84,  280,   46], dtype=int64)

# %%
df['price'].describe()
# Out:
# count    17409.000000
# mean       190.626458
# std        411.494624
# min          0.000000
# 25%         75.000000
# 50%        122.000000
# 75%        200.000000
# max      15000.000000
# Name: price, dtype: float64

# %%
grouped_data = df.groupby('neighbourhood')
grouped_data.describe()
grouped_data.mean()
# Out:
#                              id       host_id  neighbourhood_group   latitude  \
# neighbourhood
# Banyule            2.875635e+07  9.824748e+07                  NaN -37.739891
# Bayside            2.790775e+07  9.216759e+07                  NaN -37.932787
# Boroondara         2.643632e+07  9.409551e+07                  NaN -37.822687
# Brimbank           3.415227e+07  1.549171e+08                  NaN -37.757327
# Cardinia           3.301975e+07  1.430270e+08                  NaN -37.993816
# Casey              3.369580e+07  1.584119e+08                  NaN -38.055518
# Darebin            2.586199e+07  8.187399e+07                  NaN -37.752804
# Frankston          3.032047e+07  1.157518e+08                  NaN -38.137924
# Glen Eira          2.710878e+07  9.758248e+07                  NaN -37.891366
# Greater Dandenong  3.182813e+07  1.750761e+08                  NaN -37.973540
# Hobsons Bay        2.900234e+07  1.128725e+08                  NaN -37.853591
# ...
